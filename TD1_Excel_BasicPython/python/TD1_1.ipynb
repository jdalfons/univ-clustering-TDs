# %%
import pandas as pd 
import matplotlib.pyplot as plt
# Out:
# /var/folders/fj/25hghm0n7n33b98vlpmy81dm0000gn/T/ipykernel_39167/1245459687.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_excel('data/produits.xlsx', sheet_name='Feuil1')
df.head()
# Out:
#                  Nom                  Categorie    Origine  Ville   Prix  \
# 0       Alice Mutton                    Viandes        CEE   Lyon  195.0
# 1      Aniseed Syrup                 Condiments  Exterieur  Paris   50.0
# 2   Boston Crab Meat  Poissons et fruits de mer  Exterieur  Paris   92.0
# 3  Camembert Pierrot          Produits laitiers  Exterieur  Paris  170.0
# 4   Carnarvon Tigers  Poissons et fruits de mer  Exterieur   Lyon  312.5
#
#    Stock  Valeur
# 0      0     0.0
# 1     25  1250.0
# 2     30  2760.0
# 3      0     0.0
# 4      0     0.0

# %% [markdown]
# ## 1
# ```
# catégorie = condiments
# ```

# %%
q1 = df.loc[(df['Categorie']=='Condiments')] 
q1
# Out:
#                                  Nom   Categorie    Origine  Ville    Prix  \
# 1                      Aniseed Syrup  Condiments  Exterieur  Paris   50.00
# 8        Chef Antons Cajun Seasoning  Condiments        CEE   Lyon  110.00
# 9              Chef Antons Gumbo Mix  Condiments        CEE  Paris  106.75
# 16                      Genen Shouyu  Condiments        CEE  Paris   77.50
# 19       Grandmas Boysenberry Spread  Condiments  Exterieur   Lyon  125.00
# 23                      Gula Malacca  Condiments        CEE  Paris   97.25
# 34  Louisiana Fiery Hot Pepper Sauce  Condiments        CEE  Paris  105.25
# 35         Louisiana Hot Spiced Okra  Condiments        CEE  Paris   85.00
# 42        Northwoods Cranberry Sauce  Condiments  Exterieur   Lyon  200.00
# 44   Original Frankfurter grüne Soße  Condiments  Exterieur   Lyon   65.00
# 63                     Sirop derable  Condiments  Exterieur  Paris  142.50
# ...

# %% [markdown]
# ## 2. catégorie = condiments et origine = CEE

# %%
q2 = df.loc[(df['Categorie'].isin(['Condiments']))  & (df['Origine'] == 'CEE')]
q2
# Out:
#                                  Nom   Categorie Origine  Ville    Prix  \
# 8        Chef Antons Cajun Seasoning  Condiments     CEE   Lyon  110.00
# 9              Chef Antons Gumbo Mix  Condiments     CEE  Paris  106.75
# 16                      Genen Shouyu  Condiments     CEE  Paris   77.50
# 23                      Gula Malacca  Condiments     CEE  Paris   97.25
# 34  Louisiana Fiery Hot Pepper Sauce  Condiments     CEE  Paris  105.25
# 35         Louisiana Hot Spiced Okra  Condiments     CEE  Paris   85.00
#
#     Stock   Valeur
# 8       0     0.00
# 9       0     0.00
# 16      5   387.50
# 23     15  1458.75
# 34      0     0.00
# 35     20  1700.00

# %% [markdown]
# # 3. catégorie = boissons et prix > 100

# %%
q3 = df.loc[(df['Categorie'].isin(['Boissons']))  & (df['Prix'] > float(100))]
q3
# Out:
#               Nom Categorie    Origine  Ville    Prix  Stock   Valeur
# 11  Côte de Blaye  Boissons        CEE  Paris  1317.5     15  19762.5
# 28    Ipoh Coffee  Boissons  Exterieur  Paris   230.0     25   5750.0

# %% [markdown]
# # 4. catégorie = condiments et origine = CEE et prix > 100

# %%
q4 = df.loc[(df['Categorie'].isin(['Condiments']))  & (df['Valeur'] > float(100))]
q4
# Out:
#                                 Nom   Categorie    Origine  Ville    Prix  \
# 1                     Aniseed Syrup  Condiments  Exterieur  Paris   50.00
# 16                     Genen Shouyu  Condiments        CEE  Paris   77.50
# 19      Grandmas Boysenberry Spread  Condiments  Exterieur   Lyon  125.00
# 23                     Gula Malacca  Condiments        CEE  Paris   97.25
# 35        Louisiana Hot Spiced Okra  Condiments        CEE  Paris   85.00
# 44  Original Frankfurter grüne Soße  Condiments  Exterieur   Lyon   65.00
# 63                    Sirop derable  Condiments  Exterieur  Paris  142.50
# 74                     Vegie-spread  Condiments  Exterieur  Paris  219.50
#
#     Stock   Valeur
# 1      25  1250.00
# 16      5   387.50
# 19     25  3125.00
# 23     15  1458.75
# 35     20  1700.00
# 44     15   975.00
# 63     25  3562.50
# 74      5  1097.50

# %% [markdown]
# # 5. catégorie = boissons ou catégorie = condiments

# %%
q5 = df.loc[(df['Categorie'].isin(['Condiments', 'Boissons']))]
q5
# Out:
#                                  Nom   Categorie    Origine  Ville     Prix  \
# 1                      Aniseed Syrup  Condiments  Exterieur  Paris    50.00
# 5                               Chai    Boissons        CEE   Lyon    90.00
# 6                              Chang    Boissons  Exterieur   Lyon    95.00
# 7                   Chartreuse verte    Boissons  Exterieur   Lyon    90.00
# 8        Chef Antons Cajun Seasoning  Condiments        CEE   Lyon   110.00
# 9              Chef Antons Gumbo Mix  Condiments        CEE  Paris   106.75
# 11                     Côte de Blaye    Boissons        CEE  Paris  1317.50
# 16                      Genen Shouyu  Condiments        CEE  Paris    77.50
# 19       Grandmas Boysenberry Spread  Condiments  Exterieur   Lyon   125.00
# 21                Guarana Fantastica    Boissons  Exterieur   Lyon    22.50
# 23                      Gula Malacca  Condiments        CEE  Paris    97.25
# ...

# %% [markdown]
# ## 6. (catégorie = boissons et origine = cee) OU (catégorie = condiment et origine = extérieur)

# %%
q6 = df.loc[(df['Categorie'].isin(['Condiments', 'Boissons']))& (df['Origine'].isin(['CEE', 'Exterieur']))]
q6
#
# Out:
#                                  Nom   Categorie    Origine  Ville     Prix  \
# 1                      Aniseed Syrup  Condiments  Exterieur  Paris    50.00
# 5                               Chai    Boissons        CEE   Lyon    90.00
# 6                              Chang    Boissons  Exterieur   Lyon    95.00
# 7                   Chartreuse verte    Boissons  Exterieur   Lyon    90.00
# 8        Chef Antons Cajun Seasoning  Condiments        CEE   Lyon   110.00
# 9              Chef Antons Gumbo Mix  Condiments        CEE  Paris   106.75
# 11                     Côte de Blaye    Boissons        CEE  Paris  1317.50
# 16                      Genen Shouyu  Condiments        CEE  Paris    77.50
# 19       Grandmas Boysenberry Spread  Condiments  Exterieur   Lyon   125.00
# 21                Guarana Fantastica    Boissons  Exterieur   Lyon    22.50
# 23                      Gula Malacca  Condiments        CEE  Paris    97.25
# ...

# %% [markdown]
# ## 7. prix > 70 et prix <=100

# %%
q7 = df.loc[(df['Prix'] > float(70)) & (df['Prix'] <= float(100))]
q7
# Out:
#                           Nom                  Categorie    Origine  Ville  \
# 2            Boston Crab Meat  Poissons et fruits de mer  Exterieur  Paris
# 5                        Chai                   Boissons        CEE   Lyon
# 6                       Chang                   Boissons  Exterieur   Lyon
# 7            Chartreuse verte                   Boissons  Exterieur   Lyon
# 16               Genen Shouyu                 Condiments        CEE  Paris
# 23               Gula Malacca                 Condiments        CEE  Paris
# 27                Inlagd Sill  Poissons et fruits de mer  Exterieur  Paris
# 31               Lakkalikoori                   Boissons        CEE   Lyon
# 35  Louisiana Hot Spiced Okra                 Condiments        CEE  Paris
# 38                   Maxilaku                   Desserts        CEE   Lyon
# 45              Outback Lager                   Boissons  Exterieur   Lyon
# ...

# %% [markdown]
# # 8. Lister les aliments dont le prix est compris entre 100 et 200, et qui sont des « viandes »

# %%
q8 = df.loc[
    (df['Prix'].between(float(100), float(200)))
    &             
    (df['Categorie'].isin(['Viandes']))] 
q8
# Out:
#               Nom Categorie Origine  Ville   Prix  Stock  Valeur
# 0    Alice Mutton   Viandes     CEE   Lyon  195.0      0     0.0
# 46   Pate chinois   Viandes     CEE   Lyon  120.0     20  2400.0
# 48  Perth Pasties   Viandes     CEE  Paris  164.0      0     0.0

# %% [markdown]
# # 9. Lister les 15 produits les moins chers (cf. piste possible instruction n°22)

# %%
q9 =df.sort_values(by='Prix', ascending=True).head(15)
q9
# Out:
#                                Nom                  Categorie    Origine  \
# 15                         Geitost          Produits laitiers        CEE
# 21              Guarana Fantastica                   Boissons  Exterieur
# 30                           Konbu  Poissons et fruits de mer        CEE
# 13                        Filo Mix          Pates et cereales  Exterieur
# 70                       Tourtiere                    Viandes        CEE
# 53            Rhonbrau Klosterbier                   Boissons        CEE
# 71                        Tunnbrod          Pates et cereales        CEE
# 67      Teatime Chocolate Biscuits                   Desserts  Exterieur
# 55                     Røgede sild  Poissons et fruits de mer  Exterieur
# 76                   Zaanse koeken                   Desserts  Exterieur
# 29  Jacks New England Clam Chowder  Poissons et fruits de mer  Exterieur
# 33                   Longlife Tofu              Produits secs  Exterieur
# ...

# %% [markdown]
# # 10. Calculer la moyenne de prix des boissons distribuées à Lyon (pivot_table)

# %%
q10 = df['Prix'].loc[(df['Categorie'].isin(['Boissons'])) & (df['Ville'].isin(['Lyon']))].mean()
q10
# Out:
# 76.94444444444444

# %% [markdown]
# # 11. Quels sont les 5 produits les moins chers vendus à Lyon ?

# %%
q11 = df.loc[(df['Ville'].isin(['Lyon']))].sort_values(by='Prix', ascending=True).head(5)
q11
# Out:
#                            Nom                  Categorie    Origine Ville  \
# 15                     Geitost          Produits laitiers        CEE  Lyon
# 21          Guarana Fantastica                   Boissons  Exterieur  Lyon
# 30                       Konbu  Poissons et fruits de mer        CEE  Lyon
# 67  Teatime Chocolate Biscuits                   Desserts  Exterieur  Lyon
# 76               Zaanse koeken                   Desserts  Exterieur  Lyon
#
#     Prix  Stock  Valeur
# 15  12.5     20   250.0
# 21  22.5      0     0.0
# 30  30.0      5   150.0
# 67  46.0      5   230.0
# 76  47.5      0     0.0
